# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../raw_data/rawg_user_games.csv')
# Out:
# /Users/zongyizhu/.pyenv/versions/3.8.6/envs/game_one/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3155: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df
# Out:
#         user_id  game_id                            game_slug  \
# 0             1   446900         high-rise-a-puzzle-cityscape
# 1             1   264830                             twinfold
# 2             1    58443                      pocket-run-pool
# 3             1    51288                           cinco-paus
# 4             1    21889  desert-fox-the-battle-of-el-alamein
# ...         ...      ...                                  ...
# 255492  rasha27     5578                                 grid
# 255493  rasha27   326292                            fall-guys
# 255494  rasha27     2572                           dirt-rally
# 255495  rasha27     4003                               grid-2
# 255496  rasha27     3272                        rocket-league
#
#                                    game_name  user_rating  metacritic  \
# 0             High Rise - A Puzzle Cityscape            4         NaN
# 1                                   Twinfold            5         NaN
# ...

# %%
df_note = df[df['user_rating']>0]

# %%
df_note.sort_values('user_rating')
# Out:
#         user_id  game_id                      game_slug  \
# 75763       287    14166                         detour
# 236460      901    15507                          chasm
# 32773       146    28597                         nhl-14
# 236458      901    14085             seasons-after-fall
# 236446      901      258  a-kings-tale-final-fantasy-xv
# ...         ...      ...                            ...
# 231538      875    10419                     subnautica
# 120772      465    29171              the-evil-within-2
# 231534      875    21926      uncharted-the-lost-legacy
# 49810       202    39707                  god-of-war-ii
# 255496  rasha27     3272                  rocket-league
#
#                               game_name  user_rating  metacritic  rawg_rating  \
# 75763                            DETOUR            1         NaN         1.72
# 236460                            Chasm            1         NaN         3.61
# ...

# %%
df_note.groupby('user_id').count().sort_values('user_rating',ascending=False )
# Out:
#          game_id  game_slug  game_name  user_rating  metacritic  rawg_rating  \
# user_id
# 655         1272       1272       1272         1272         670         1272
# 989          852        852        852          852         264          852
# 934          623        623        623          623         367          623
# 9            584        584        584          584         413          584
# 893          564        564        564          564         455          564
# ...          ...        ...        ...          ...         ...          ...
# 909            1          1          1            1           1            1
# 712            1          1          1            1           1            1
# 163            1          1          1            1           1            1
# 276            1          1          1            1           1            1
# 476            1          1          1            1           1            1
#
#          released  play_time
# ...
